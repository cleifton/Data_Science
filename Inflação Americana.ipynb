# %% [markdown]
# <a href="https://colab.research.google.com/github/cleifton/Data_Science/blob/master/Infla%C3%A7%C3%A3o%20Americana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns

auth.authenticate_user() 
gauth = GoogleAuth() 
gauth.credentials = GoogleCredentials.get_application_default() 
drive = GoogleDrive(gauth)


from pydrive.auth import GoogleAuth 
from pydrive.drive import GoogleDrive 
from google.colab import auth 
from oauth2client.client import GoogleCredentials

# %%
link='https://drive.google.com/file/d/1prm2iRNgNyvYt4sZg8yfVgtkjBd65_5_/view?usp=sharing'
id = link.split("/")[-2] 
downloaded = drive.CreateFile({'id':id})  
downloaded.GetContentFile('inflation.csv')     
df = pd.read_csv('inflation.csv') 
df
print(df)
# Out:
#      Unnamed: 0    Year      Jan      Feb      Mar      Apr      May      Jun  \
# 0             0  1913.0    9.800    9.800    9.800    9.800    9.700    9.800
# 1             1  1914.0   10.000    9.900    9.900    9.800    9.900    9.900
# 2             2  1915.0   10.100   10.000    9.900   10.000   10.100   10.100
# 3             3  1916.0   10.400   10.400   10.500   10.600   10.700   10.800
# 4             4  1917.0   11.700   12.000   12.000   12.600   12.800   13.000
# ..          ...     ...      ...      ...      ...      ...      ...      ...
# 105         105  2018.0  247.867  248.991  249.554  250.546  251.588  251.989
# 106         106  2019.0  251.712  252.776  254.202  255.548  256.092  256.143
# 107         107  2020.0  257.971  258.678  258.115  256.389  256.394  257.797
# 108         108  2021.0  261.582  263.014  264.877  267.054  269.195  271.696
# 109         109  2022.0  281.148  283.716  287.504  289.109      NaN      NaN
#
#          Jul      Aug      Sep      Oct      Nov      Dec
# 0      9.900    9.900   10.000   10.000   10.100   10.000
# 1     10.000   10.200   10.200   10.100   10.200   10.100
# 2     10.100   10.100   10.100   10.200   10.300   10.300
# 3     10.800   10.900   11.100   11.300   11.500   11.600
# 4     12.800   13.000   13.300   13.500   13.500   13.700
# ..       ...      ...      ...      ...      ...      ...
# 105  252.006  252.146  252.439  252.885  252.038  251.233
# 106  256.571  256.558  256.759  257.346  257.208  256.974
# 107  259.101  259.918  260.280  260.388  260.229  260.474
# 108  273.003  273.567  274.310  276.589  277.948  278.802
# 109      NaN      NaN      NaN      NaN      NaN      NaN
#
# [110 rows x 14 columns]

# %%
df
# Out:
#      Unnamed: 0    Year      Jan      Feb      Mar      Apr      May      Jun  \
# 0             0  1913.0    9.800    9.800    9.800    9.800    9.700    9.800
# 1             1  1914.0   10.000    9.900    9.900    9.800    9.900    9.900
# 2             2  1915.0   10.100   10.000    9.900   10.000   10.100   10.100
# 3             3  1916.0   10.400   10.400   10.500   10.600   10.700   10.800
# 25%    1940.250000   17.425000   17.400000   17.325000   17.425000
# 50%    1967.500000   33.500000   33.550000   33.650000   33.750000
# 75%    1994.750000  149.275000  149.850000  150.350000  150.775000
# max    2022.000000  281.148000  283.716000  287.504000  289.109000
#
#               May         Jun         Jul         Aug         Sep         Oct  \
# count  109.000000  109.000000  109.000000  109.000000  109.000000  109.000000
# mean    83.182339   83.458789   83.638954   83.818119   84.066394   84.202312
# std     81.448461   81.663445   81.725646   81.843079   82.004651   82.038188
# min      9.700000    9.800000    9.900000    9.900000   10.000000   10.000000
# 25%     17.500000   17.600000   17.500000   17.700000   17.500000   17.600000
# 50%     33.200000   33.300000   33.400000   33.500000   33.600000   33.700000
# 75%    147.500000  148.000000  148.400000  149.000000  149.400000  149.500000
# max    269.195000  271.696000  273.003000  273.567000  274.310000  276.589000
#
#               Nov         Dec
# count  109.000000  109.000000
# mean    84.200798   84.170550
# std     81.895101   81.763823
# min     10.100000   10.000000
# 25%     17.700000   17.700000
# 50%     33.800000   33.900000
# 75%    149.700000  149.700000
# max    277.948000  278.802000

# %%
#plot January CPI each year
column = [df.mean(axis = 1) for i in df]
df.plot(x='Year', y='Jan')

# %%
#average CPI per year
avg_df = df
avg_df = avg_df.drop(columns = 'Year')
column = avg_df.mean(axis=1)
column
# Out:
# 0        9.883333
# 1       10.016667
# 2       10.108333
# 3       10.883333
# 4       12.825000
#           ...
# 105    251.106833
# 106    255.657417
# 107    258.811167
# 108    270.969750
# 109    285.369250
# Length: 110, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Year'], column)

# %%
#average CPI each month
for i in range(12): 
    print(df.iloc[i + 1].mean())
# Out:
# 156.47692307692307
# 156.6384615384615
# 157.43076923076924
# 159.29999999999998
# 161.42307692307693
# 163.6153846153846
# 166.19230769230774
# 164.24615384615387
# 163.30769230769232
# 163.6615384615385
# 163.80769230769226
# 164.26923076923075

# %%
#inflação durante a presidência de Biden
biden_df = avg_df.iloc[108:110]
biden_df_row = biden_df.to_numpy().flatten()
biden_df_row = biden_df_row[0:18]
columns = [i for i in range(18)]
plt.xticks(range(0, 18, 1))
plt.yticks(range(int(min(biden_df_row)), int(max(biden_df_row)), 2))
plt.scatter(columns, biden_df_row)
plt.xlabel('Month #')
# Out:
# Text(0.5, 0, 'Month #')

# %%
#inflação durante a presidência do presidente Trump
trump_df = avg_df.iloc[103:107]
trump_df_row = trump_df.to_numpy().flatten()
trump_df_row = trump_df_row[0:48]
columns = [i for i in range(48)]
plt.xticks(range(0, 48, 4))
plt.yticks(range(int(min(trump_df_row)), int(max(trump_df_row)), 2))
plt.scatter(columns, trump_df_row)
plt.xlabel('Month #')
# Out:
# Text(0.5, 0, 'Month #')
